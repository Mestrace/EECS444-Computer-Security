# %%
# The name input to the program
name = "richy".upper()
# Sum the ASCII code of all the upper case characters
sum = 0
for s in name:
    sum += ord(s)
# do the computation
serial = sum ^ 0x1234 ^ 0x5678
serial
# Out:
# 17715
